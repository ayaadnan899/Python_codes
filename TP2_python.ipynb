# %%
#ex1:Q1
import numpy as np
y=np.array([5,15,25,35,40,45,50,55,60,65,70])

# %%
print(y)
# Out:
# [ 5 15 25 35 40 45 50 55 60 65 70]

# %%
#Q2
y.ndim
# Out:
# 1

# %%
y.size
# Out:
# 11

# %%
print(y[2])
# Out:
# 25

# %%
#Q3
print(y[2:5])
# Out:
# [25 35 40]

# %%
#Q4
indice=[1,2,5,8]
print(y[indice])
# Out:
# [15 25 45 60]

# %%
#Q5
print(y[::2])
# Out:
# [ 5 25 40 50 60 70]

# %%
#Q6
print(y[y>0])
# Out:
# [ 5 15 25 35 40 45 50 55 60 65 70]

# %%
#Q7
print(y[(y%2==0)&(y%5==0)])
# Out:
# [40 50 60 70]

# %%
#Q8
print(y[(y%3==0)])
# Out:
# [15 45 60]

# %%
#Q9
print(y.sum())
print(y.max())
print(y.min())
print(y.mean())
# Out:
# 465
# 70
# 5
# 42.27272727272727

# %%
#Q10
print(y.argmin())
print(y.argmax())
# Out:
# 0
# 10

# %%
#Q11 pour calculer la varience de y
print(np.var(y))
#print(1/y.size()*np.sum((y-np.mean(y))**2)
# Out:
# 392.5619834710744

# %%
#Q12 ecart-type de y
print(np.std(y))
# Out:
# 19.81317701609397

# %%
#Q13
print(np.median(y))
# Out:
# 45.0

# %%
#Q14
normaliser=(y-y.min())/(y.max()-y.min())
#y_moy=y.mean()
#y_mediane=y.std
#norm=(y-y_moy)/y_mediane

# %%
print(normaliser)
# Out:
# [0.         0.15384615 0.30769231 0.46153846 0.53846154 0.61538462
#  0.69230769 0.76923077 0.84615385 0.92307692 1.        ]

# %%
#Q15
print(np.exp(y))
# Out:
# [1.48413159e+02 3.26901737e+06 7.20048993e+10 1.58601345e+15
#  2.35385267e+17 3.49342711e+19 5.18470553e+21 7.69478527e+23
#  1.14200739e+26 1.69488924e+28 2.51543867e+30]

# %%
#Q16
element_sup=y[y>(y.mean())]
print(element_sup)
# Out:
# [45 50 55 60 65 70]

# %%
#Q17
y[y>40]=40
print(y)
# Out:
# [ 5 15 25 35 40 40 40 40 40 40 40]

# %%
#Q18
y[y%2!=0]=-1
print(y)
# Out:
# [-1 -1 -1 -1 40 40 40 40 40 40 40]

# %%
#Q19
y_trie=np.sort(y)
print(y_trie)
# Out:
# [-1 -1 -1 -1 40 40 40 40 40 40 40]

# %%
y_decroi_trie=y[np.argsort(-y)]
print(y_decroi_trie)
# Out:
# [40 40 40 40 40 40 40 -1 -1 -1 -1]

# %%
#Q20
indice=np.where(y>50)
print(indice)
# Out:
# (array([ 7,  8,  9, 10]),)

# %%
#Q21
positif=np.all(y>0)
print(positif)
# Out:
# True

# %%
#Q22
res=np.any(y>60)
print(res)
# Out:
# False

# %%
#Q23
new_table=y.reshape(11,1)
print(new_table)
# Out:
# [[-1]
#  [-1]
#  [-1]
#  [-1]
#  [40]
#  [40]
#  [40]
#  [40]
#  [40]
#  [40]
#  [40]]

# %%
#Q24
np.save("y_table.npy",y)

# %%
#Q25
x=np.load("y_table.npy")
print(x)
# Out:
# [-1 -1 -1 -1 40 40 40 40 40 40 40]

# %%
#Ex03:Q1
import numpy as np
import matplotlib.pyplot as plt
x=np.linspace(0,4*np.pi,100)

# %%
print("x: ",x)
# Out:
# x:  [ 0.          0.12693304  0.25386607  0.38079911  0.50773215  0.63466518
#   0.76159822  0.88853126  1.01546429  1.14239733  1.26933037  1.3962634
#   1.52319644  1.65012947  1.77706251  1.90399555  2.03092858  2.15786162
#   2.28479466  2.41172769  2.53866073  2.66559377  2.7925268   2.91945984
#   3.04639288  3.17332591  3.30025895  3.42719199  3.55412502  3.68105806
#   3.8079911   3.93492413  4.06185717  4.1887902   4.31572324  4.44265628
#   4.56958931  4.69652235  4.82345539  4.95038842  5.07732146  5.2042545
#   5.33118753  5.45812057  5.58505361  5.71198664  5.83891968  5.96585272
#   6.09278575  6.21971879  6.34665183  6.47358486  6.6005179   6.72745093
#   6.85438397  6.98131701  7.10825004  7.23518308  7.36211612  7.48904915
#   7.61598219  7.74291523  7.86984826  7.9967813   8.12371434  8.25064737
#   8.37758041  8.50451345  8.63144648  8.75837952  8.88531256  9.01224559
#   9.13917863  9.26611167  9.3930447   9.51997774  9.64691077  9.77384381
# ...

# %%
#Q2
y1=2*np.sin(x)
print("y:",y1)
# Out:
# y: [ 0.00000000e+00  2.53184907e-01  5.02295974e-01  7.43324911e-01
#   9.72393472e-01  1.18581586e+00  1.38015802e+00  1.55229293e+00
#   1.69945086e+00  1.81926399e+00  1.90980448e+00  1.96961551e+00
#   1.99773468e+00  1.99370955e+00  1.95760489e+00  1.89000164e+00
#   1.79198755e+00  1.66513971e+00  1.51149915e+00  1.33353800e+00
#   1.13411973e+00  9.16453043e-01  6.84040287e-01  4.40621066e-01
#   1.90112087e-01 -6.34558670e-02 -3.16002792e-01 -5.63465114e-01
#  -8.01861071e-01 -1.02735478e+00 -1.23631797e+00 -1.42538834e+00
#  -1.59152368e+00 -1.73205081e+00 -1.84470859e+00 -1.92768432e+00
#  -1.97964288e+00 -1.99974826e+00 -1.98767693e+00 -1.94362314e+00
#  -1.86829572e+00 -1.76290673e+00 -1.62915190e+00 -1.46918342e+00
#  -1.28557522e+00 -1.08128163e+00 -8.59589824e-01 -6.24066891e-01
#  -3.78502489e-01 -1.26847839e-01  1.26847839e-01  3.78502489e-01
#   6.24066891e-01  8.59589824e-01  1.08128163e+00  1.28557522e+00
# ...

# %%
#Q3
plt.figure()
plt.plot(x,y1,label='y1 = 2*sin(x)', color='blue',linestyle='-')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Graphique de y1')
plt.legend()
plt.show()

# %%
#Q4
y2=3*np.sin(x+np.pi)
print("y:",y)
# Out:
# y: [ 5 15 25 35 40 45 50 55 60 65 70]

# %%
#Q5
plt.figure()
plt.plot(x,y1,label='y1 = 2*sin(x)', color='blue',linestyle='-')
plt.plot(x,y2,label='y2 = 3*sin(x+pi)', color='red',linestyle='-')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Graphique de y1 et y2')
plt.legend()
plt.show()

# %%
#Q6
